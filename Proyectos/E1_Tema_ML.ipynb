# %% [markdown]
# # Primera entrega ML

# %% [markdown]
# ### Título de proyecto

# %%
# Escribir el título de proyecto en Markdown
titulo = "Modelo de prediccion de inversion en medios pagados digitales"

# %% [markdown]
# ### Tema

# %%
tema = "En base al analisis de resultados a los niveles de inversion en 5 paises, se busca predecir la inversion necesaria para proyectos nuevos"
# Breve descripción del proyecto

# %% [markdown]
# ### Datasets y fuentes alternativas de datos
# Incluye aquí una breve descripción del dataset o datasets para tu proyecto. Incluye también las fuentes de cada uno de ellos.

# %%
tipo_ml = "Supervisado. Linear Regresion" # Regresión? Clasificación?
target_descr = "Ventas" # Descripción de la variable objetivo
metricas = ["impresiones", "clicks", "ventas"] # Metricas escogidas para evaluar los modelos

# %%
# dasets y enlaces de datasets en Markdown
enlaces = [] # ["www.paginacondatos.com", "www.paginawebscrapeada.com", "www.unaapi.com"]

# %%
# load dataset
# df_1.head()

import pandas as pd
df_total = pd.read_csv('data/Base_total.csv', sep=",")

# %%
df_total
# Out:
#                  Country       Week Currency code     Budget Budget type  \
# 0     Dominican_Republic  2/26/2024           USD  39.000000       Daily
# 1     Dominican_Republic  3/11/2024           USD  39.000000       Daily
# 2     Dominican_Republic  1/29/2024           USD  39.000000       Daily
# 3     Dominican_Republic   4/8/2024           USD  39.000000       Daily
# 4     Dominican_Republic  4/15/2024           USD  39.000000       Daily
# ...                  ...        ...           ...        ...         ...
# 3005           Argentina  4/15/2024           USD  30.949714       Daily
# 3006           Argentina  3/11/2024           USD   9.714286       Daily
# 3007           Argentina  4/22/2024           USD  20.571429       Daily
# 3008           Argentina  2/12/2024           USD  20.571429       Daily
# 3009           Argentina  3/25/2024           USD   9.714286       Daily
#
#         Campaign type    Impr. Interactions        Cost Engagements  Purchase  \
# ...

# %%
# load dataset
# df_2.head()
